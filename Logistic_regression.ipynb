# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-ae4706e6-916b-4deb-8625-435465838acf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ae4706e6-916b-4deb-8625-435465838acf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
class LogisticRegressionScratch() :
    def __init__( self, learning_rate, iterations ) :
        self.learning_rate = learning_rate
        self.iterations = iterations

    def fit( self, X, Y ) :

        self.m, self.n = X.shape

        self.W = np.zeros( self.n )
        self.b = 0
        self.X = X
        self.Y = Y


        for i in range( self.iterations ) :
            self.update_weights()
        return self


    def update_weights( self ) :
        A = 1 / ( 1 + np.exp( - ( self.X.dot( self.W ) + self.b ) ) )

        tmp = ( A - self.Y.T )
        tmp = np.reshape( tmp, self.m )
        dW = np.dot( self.X.T, tmp ) / self.m
        db = np.sum( tmp ) / self.m

        self.W = self.W - self.learning_rate * dW
        self.b = self.b - self.learning_rate * db

        return self


    def predict( self, X ) :
        Z = 1 / ( 1 + np.exp( - ( X.dot( self.W ) + self.b ) ) )
        Y = np.where( Z > 0.5, 1, 0 )
        return Y

# %%
df= pd.read_csv( "ds1_train.csv" )
dt = pd.read_csv("ds1_test.csv")
X_train = df.iloc[:,:-1].values
Y_train = df.iloc[:,-1:].values
X_test = dt.iloc[:,:-1].values
Y_test = dt.iloc[:,-1:].values

# %%
model = LogisticRegressionScratch( learning_rate = 0.01, iterations = 1000 )

model.fit( X_train, Y_train )

Y_pred = model.predict( X_test )

Y_pred2 = model.predict( X_train )



correctly_classified = 0

correctly_classified1 = 0

count = 0

for count in range( np.size( Y_pred ) ) :

    if Y_test[count] == Y_pred[count] :
            correctly_classified = correctly_classified + 1

    if Y_train[count] == Y_pred2[count] :
            correctly_classified1 = correctly_classified1 + 1

    count = count + 1

print( "Accuracy of model on train data % : ", (correctly_classified / count ) * 100 )

print( "Accuracy of model on test data % : ", (correctly_classified1 / count ) * 100 )
# Out:
# Accuracy of model on train data % :  78.0
# Accuracy of model on test data % :  95.0

# %%
from sklearn.linear_model import LogisticRegression

import warnings
warnings.filterwarnings( "ignore" )

lib_model = LogisticRegression()
lib_model.fit( X_train , Y_train )

Y_pred1 = lib_model.predict( X_test )
Y_pred3 = lib_model.predict( X_train )

correctly_classified2 = 0

correctly_classified3 = 0

count1 = 0
for count in range( np.size( Y_pred1 ) ) :

    if Y_test[count1] == Y_pred1[count1] :
        correctly_classified2 = correctly_classified2 + 1

    if Y_train[count1] == Y_pred3[count1] :
        correctly_classified3 = correctly_classified3 + 1

    count1 = count1 + 1


print( "Accuracy on test set by sklearn model   :  ", ( correctly_classified2 / count1 ) * 100 )

print( "Accuracy on train set by sklearn model   :  ", ( correctly_classified3 / count1 ) * 100 )
# Out:
# Accuracy on test set by sklearn model   :   90.0
# Accuracy on train set by sklearn model   :   88.0
